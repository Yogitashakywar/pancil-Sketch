# %% [markdown]
# # LetsGrowMore(LGMVIPMAR2022)
#
# ### Task4 - Image to Pencil Sketch with Python
#
# ## Author Name - Sachinkumar Ganesh Navgale

# %%
import cv2
import numpy as np
from PIL import Image
from IPython.display import display

# %%
image = cv2.imread('Sn.jpg')
# cv2.imshow("Original Image", image)
# cv2.waitKey(0)
image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
display(Image.fromarray(image))
# Out:
# <PIL.Image.Image image mode=RGB size=760x475 at 0x1C0A8494340>

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
display(Image.fromarray(gray_image))
# Out:
# <PIL.Image.Image image mode=L size=760x475 at 0x1C0AA0D17F0>

# %%
inverted_image = cv2.bitwise_not(gray_image)
display(Image.fromarray(inverted_image))
# Out:
# <PIL.Image.Image image mode=L size=760x475 at 0x1C0A84A3E20>

# %%
blurred_image = cv2.GaussianBlur(inverted_image, (21, 21), 0)
display(Image.fromarray(blurred_image))
# Out:
# <PIL.Image.Image image mode=L size=760x475 at 0x1C0A849D7C0>

# %%
inverted_blurred = cv2.bitwise_not(blurred_image)
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=150)
display(Image.fromarray(pencil_sketch))
# Out:
# <PIL.Image.Image image mode=L size=760x475 at 0x1C0AA0D1940>

# %% [markdown]
# # Thank You!!!
